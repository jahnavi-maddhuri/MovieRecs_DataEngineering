# %%
import pandas as pd
import numpy as np

pd.set_option("mode.copy_on_write", True)

# %%
movie_pd = pd.DataFrame()
# 47400
import requests

for page in range(1, 500):
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={page}&sort_by=popularity.desc"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzMDBlYTAyNTNkMWQyN2U4MjdjMjBiOTFmYzYwMmVhYyIsIm5iZiI6MTczMjU1NTk0My43NDEsInN1YiI6IjY3NDRiNGE3Y2ZkMjRjM2E3YWFiOWEyOSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.9PoVKb84fj-6DFtvW73XjjBjA-qY_bqaPpwom9B2Zpg",
    }

    response = requests.get(url, headers=headers)
    results = response.json()["results"]
    results_pd = pd.DataFrame(results)
    movie_pd = pd.concat([movie_pd, results_pd], ignore_index=True)

# movie_pd.to_csv("movies.csv")

# %%
movie_pd.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg        [878, 28, 12]   912649
# 1  False  /tElnmtQ6yz1PjN1kePNl8yMSb59.jpg  [16, 12, 10751, 35]  1241982
# 2  False  /au3o84ub27qTZiMiEc9UYzN74V3.jpg        [28, 878, 53]  1035048
# 3  False  /nOoGIymGBNtA7AEN0B6nshSEQ1p.jpg         [28, 80, 53]   974453
# 4  False  /m2hs6YPVrzjvRC21SE9BeXtgqFW.jpg  [16, 9648, 878, 28]  1299652
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en                Moana 2
# 2                en              Elevation
# 3                en             Absolution
# 4                en   Watchmen: Chapter II
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...   13535.697
# 1  After receiving an unexpected call from her wa...    5311.527
# 2  A single father and two women venture from the...    3106.853
# 3  An aging ex-boxer gangster working as muscle f...    2261.486
# 4  Suspicious of the events ensnaring their forme...    1781.131
#
#                         poster_path release_date                  title  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22  Venom: The Last Dance
# 1  /yh64qw9mgXBvlaWDi7Q9tpUBAvH.jpg   2024-11-21                Moana 2
# 2  /uQhYBxOVFU6s9agD49FnGHwJqG5.jpg   2024-11-07              Elevation
# 3  /cNtAslrDhk1i3IOZ16vF7df6lMy.jpg   2024-10-31             Absolution
# 4  /4rBObJFpiWJOG7aIlRrOUniAkBs.jpg   2024-11-25   Watchmen: Chapter II
#
#    video  vote_average  vote_count
# 0  False         6.415        1016
# 1  False         6.900         412
# 2  False         6.400         124
# 3  False         6.100         119
# 4  False         7.700          41

# %%
genres = [
    {"id": 28, "name": "Action"},
    {"id": 12, "name": "Adventure"},
    {"id": 16, "name": "Animation"},
    {"id": 35, "name": "Comedy"},
    {"id": 80, "name": "Crime"},
    {"id": 99, "name": "Documentary"},
    {"id": 18, "name": "Drama"},
    {"id": 10751, "name": "Family"},
    {"id": 14, "name": "Fantasy"},
    {"id": 36, "name": "History"},
    {"id": 27, "name": "Horror"},
    {"id": 10402, "name": "Music"},
    {"id": 9648, "name": "Mystery"},
    {"id": 10749, "name": "Romance"},
    {"id": 878, "name": "Science Fiction"},
    {"id": 10770, "name": "TV Movie"},
    {"id": 53, "name": "Thriller"},
    {"id": 10752, "name": "War"},
    {"id": 37, "name": "Western"},
]

genre_dict = {genre["id"]: genre["name"] for genre in genres}

# %%
genre_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
# Get genre names from ids
genre_ids = movie_pd["genre_ids"][0]
genre_names = [genre_dict.get(genre_id, "Unknown") for genre_id in genre_ids]

print(genre_names)
# Out:
# ['Science Fiction', 'Action', 'Adventure']

# %%
movie_pd["genre_names"] = movie_pd["genre_ids"].apply(
    lambda ids: [genre_dict[id] for id in ids]
)

# %%
movie_pd.head()
# Out:
#    adult                     backdrop_path            genre_ids       id  \
# 0  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg        [878, 28, 12]   912649
# 1  False  /tElnmtQ6yz1PjN1kePNl8yMSb59.jpg  [16, 12, 10751, 35]  1241982
# 2  False  /au3o84ub27qTZiMiEc9UYzN74V3.jpg        [28, 878, 53]  1035048
# 3  False  /nOoGIymGBNtA7AEN0B6nshSEQ1p.jpg         [28, 80, 53]   974453
# 4  False  /m2hs6YPVrzjvRC21SE9BeXtgqFW.jpg  [16, 9648, 878, 28]  1299652
#
#   original_language         original_title  \
# 0                en  Venom: The Last Dance
# 1                en                Moana 2
# 2                en              Elevation
# 3                en             Absolution
# 4                en   Watchmen: Chapter II
#
#                                             overview  popularity  \
# 0  Eddie and Venom are on the run. Hunted by both...   13535.697
# 1  After receiving an unexpected call from her wa...    5311.527
# 2  A single father and two women venture from the...    3106.853
# 3  An aging ex-boxer gangster working as muscle f...    2261.486
# 4  Suspicious of the events ensnaring their forme...    1781.131
#
#                         poster_path release_date                  title  \
# 0  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-22  Venom: The Last Dance
# 1  /yh64qw9mgXBvlaWDi7Q9tpUBAvH.jpg   2024-11-21                Moana 2
# 2  /uQhYBxOVFU6s9agD49FnGHwJqG5.jpg   2024-11-07              Elevation
# 3  /cNtAslrDhk1i3IOZ16vF7df6lMy.jpg   2024-10-31             Absolution
# 4  /4rBObJFpiWJOG7aIlRrOUniAkBs.jpg   2024-11-25   Watchmen: Chapter II
#
#    video  vote_average  vote_count  \
# 0  False         6.415        1016
# 1  False         6.900         412
# 2  False         6.400         124
# 3  False         6.100         119
# 4  False         7.700          41
#
#                                      genre_names
# 0           [Science Fiction, Action, Adventure]
# 1         [Animation, Adventure, Family, Comedy]
# 2            [Action, Science Fiction, Thriller]
# 3                      [Action, Crime, Thriller]
# 4  [Animation, Mystery, Science Fiction, Action]
